# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()

project_id = "involuted-fold-363604"
client = bigquery.Client(project=project_id)

query = """
Select * from `bigquery-public-data`.austin_bikeshare.bikeshare_trips
limit 5000
"""

df = client.query(query).to_dataframe()
df
# Out:
#        trip_id       subscriber_type bike_id bike_type  \
# 0     32234558              Local365   22174  electric
# 1     29712533               Local31   21739  electric
# 2     29651222               Local31   21829  electric
# 3     29629276               Local31   19935  electric
# 4     29643021               Local31   18971  electric
# ...        ...                   ...     ...       ...
# 4995  30249381  24 Hour Walk Up Pass     230   classic
# 4996  30304160              Local365   19271  electric
# 4997  30304280              Local365   19479  electric
# 4998  30307154       Pay-as-you-ride   19319  electric
# 4999  30318226              Explorer     877   classic
#
#                     start_time  start_station_id  \
# 0    2023-12-31 16:15:36+00:00              3686
# 1    2023-05-24 23:13:59+00:00              2823
# 2    2023-05-17 23:17:20+00:00              2823
# 3    2023-05-15 10:41:47+00:00              2823
# 4    2023-05-16 23:24:18+00:00              2823
# ...

# %%
df.groupby(['subscriber_type','bike_type']).agg('sum')
# Out:
# <ipython-input-11-b197cffd8c44>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['subscriber_type','bike_type']).agg('sum')
#                                          start_station_id  duration_minutes
# subscriber_type               bike_type
# 24 Hour Walk Up Pass          classic               63563              5160
#                               electric             301985              7718
# 3-Day Weekender               classic              199919              1174
#                               electric            1214344             12471
# Explorer                      classic              312551              2573
#                               electric            2983599             33709
# Local31                       classic              323193              3498
# ...

# %%
task1 = """
select count(*) from `bigquery-public-data`.austin_bikeshare.INFORMATION_SCHEMA.TABLES
"""

dfTask1 = client.query(task1).to_dataframe()
dfTask1
# Out:
#    f0_
# 0    2

# %%
task2 = """
select count(*) from `bigquery-public-data`.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS
where table_name = 'bikeshare_stations' and data_type = 'STRING'
"""

dfTask2 = client.query(task2).to_dataframe()
dfTask2
# Out:
#    f0_
# 0    7

# %%
task3 = """
select * from `bigquery-public-data`.austin_bikeshare.bikeshare_trips
where bike_id is not null and duration_minutes > 1000
"""

dfTask3 = client.query(task3).to_dataframe()
dfTask3
# Out:
#        trip_id     subscriber_type bike_id bike_type  \
# 0     26126810             Local31     440   classic
# 1     26126809             Local31    1439   classic
# 2     26095407     Pay-as-you-ride      57   classic
# 3     26484888            Explorer   21714  electric
# 4     26361653            Explorer   21543  electric
# ...        ...                 ...     ...       ...
# 3643  29850211            Explorer   19432  electric
# 3644  28844045  Student Membership   21485  electric
# 3645  28893573  Student Membership      57   classic
# 3646  26960908  Student Membership     610   classic
# 3647  26996194  Student Membership   21799  electric
#
#                     start_time  start_station_id         start_station_name  \
# 0    2022-03-07 17:03:23+00:00              4058  Hollow Creek/Barton Hills
# 1    2022-03-07 17:03:18+00:00              4058  Hollow Creek/Barton Hills
# 2    2022-03-02 15:49:06+00:00              4058  Hollow Creek/Barton Hills
# ...

# %%
task4 = """
select * from `bigquery-public-data`.austin_bikeshare.bikeshare_trips
where subscriber_type = 'Walk Up' and end_station_name = 'Stolen'
"""

dfTask4 = client.query(task4).to_dataframe()
dfTask4
# Out:
#     trip_id subscriber_type bike_id bike_type                start_time  \
# 0  13555129         Walk Up     578   classic 2017-01-27 01:35:26+00:00
# 1  13564817         Walk Up     393   classic 2017-01-28 04:57:28+00:00
# 2  11712091         Walk Up     327   classic 2016-09-02 06:37:15+00:00
# 3  11714202         Walk Up     122   classic 2016-09-02 09:00:56+00:00
# 4  13857913         Walk Up     135   classic 2017-02-26 14:32:45+00:00
# 5  16898448         Walk Up    1857   classic 2018-03-18 22:51:20+00:00
# 6  16863172         Walk Up    1795   classic 2018-03-14 21:23:26+00:00
# 7  17151360         Walk Up    1899   classic 2018-04-21 15:29:10+00:00
#
#    start_station_id                                 start_station_name  \
# 0              2498            Convention Center / 4th St. @ MetroRail
# 1              2561  State Capitol Visitors Garage @ San Jacinto & ...
# 2              2565                               Trinity & 6th Street
# ...
